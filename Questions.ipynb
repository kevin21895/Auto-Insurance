# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt
if int(os.environ.get("MODERN_PANDAS_EPUB", 0)):
    import prep # noqa

pd.options.display.max_rows = 10
pd.options.display.max_columns = 30
sns.set(style='ticks', context='talk')

# %%
#Reading data from the CSV File.
auto = pd.read_csv('data/Auto_Insurance_Claims_Sample.csv')
auto.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0  Bachelor           2/24/11         Employed      F   56274      Suburban
# 1  Bachelor           1/31/11       Unemployed      F       0      Suburban
# 2  Bachelor           2/19/11         Employed      F   48767      Suburban
# 3  Bachelor           1/20/11       Unemployed      M       0      Suburban
# 4  Bachelor            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy  Claim Reason  \
# 0                   1  Corporate Auto  Corporate L3     Collision
# 1                   8   Personal Auto   Personal L3  Scratch/Dent
# 2                   2   Personal Auto   Personal L3     Collision
# 3                   7  Corporate Auto  Corporate L2     Collision
# 4                   1   Personal Auto   Personal L1     Collision
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
#Renaming Column names and setting index to Customer.
column_names = {'Location Code': 'Location Type', 'Vehicle Class':'Vehicle Type', 'Monthly Premium Auto': 'Premium Per Month', 
                'Policy': 'Policy Name', 'EmploymentStatus': 'Employment Status', 'Months Since Policy Inception': 'Months Since Policy Inspection','Claim Amount':'Claim Demanded','Total Claim Amount':'Claim Sanctioned'
               ,'Effective To Date':'date'}
auto = (auto.rename(columns=column_names)
    [['Customer', 'Gender', 'Income','Employment Status','Education', 'Marital Status', 'Country','State','State Code','Location Type','Policy Name','Policy Type','Number of Policies','Premium Per Month','Coverage','Sales Channel','Vehicle Type','Vehicle Size','date','Claim Reason','Claim Demanded','Claim Sanctioned','Number of Open Complaints','Response','Months Since Last Claim','Months Since Policy Inspection']]
        .set_index('Customer', append=True)
        .rename_axis(["customer_id", "Customer"])
        .sort_index())
auto.head()
# Out:
#                      Gender  Income Employment Status Education  \
# customer_id Customer
# 0           BU79786       F   56274          Employed  Bachelor
# 1           QZ44356       F       0        Unemployed  Bachelor
# 2           AI49188       F   48767          Employed  Bachelor
# 3           WW63253       M       0        Unemployed  Bachelor
# 4           HB64268       M   43836          Employed  Bachelor
#
#                      Marital Status Country     State State Code  \
# customer_id Customer
# 0           BU79786         Married      US    Kansas         KS
# 1           QZ44356          Single      US  Nebraska         NE
# 2           AI49188         Married      US  Oklahoma         OK
# 3           WW63253         Married      US  Missouri         MO
# 4           HB64268          Single      US    Kansas         KS
#
#                      Location Type   Policy Name     Policy Type  \
# customer_id Customer
# 0           BU79786       Suburban  Corporate L3  Corporate Auto
# 1           QZ44356       Suburban   Personal L3   Personal Auto
# 2           AI49188       Suburban   Personal L3   Personal Auto
# 3           WW63253       Suburban  Corporate L2  Corporate Auto
# 4           HB64268          Rural   Personal L1   Personal Auto
#
#                       Number of Policies  Premium Per Month  Coverage  \
# customer_id Customer
# 0           BU79786                    1                 69     Basic
# 1           QZ44356                    8                 94  Extended
# 2           AI49188                    2                108   Premium
# 3           WW63253                    7                106     Basic
# 4           HB64268                    1                 73     Basic
#
#                      Sales Channel   Vehicle Type Vehicle Size     date  \
# customer_id Customer
# 0           BU79786          Agent   Two-Door Car      Medsize  2/24/11
# 1           QZ44356          Agent  Four-Door Car      Medsize  1/31/11
# 2           AI49188          Agent   Two-Door Car      Medsize  2/19/11
# 3           WW63253    Call Center            SUV      Medsize  1/20/11
# 4           HB64268          Agent  Four-Door Car      Medsize   2/3/11
#
#                       Claim Reason  Claim Demanded  Claim Sanctioned  \
# customer_id Customer
# 0           BU79786      Collision      276.351928        384.811147
# 1           QZ44356   Scratch/Dent      697.953590       1131.464935
# 2           AI49188      Collision     1288.743165        566.472247
# 3           WW63253      Collision      764.586183        529.881344
# 4           HB64268      Collision      281.369258        138.130879
#
#                       Number of Open Complaints Response  \
# customer_id Customer
# 0           BU79786                           0       No
# 1           QZ44356                           0       No
# 2           AI49188                           0       No
# 3           WW63253                           0       No
# 4           HB64268                           0       No
#
#                       Months Since Last Claim  Months Since Policy Inspection
# customer_id Customer
# 0           BU79786                        32                               5
# 1           QZ44356                        13                              42
# 2           AI49188                        18                              38
# 3           WW63253                        18                              65
# 4           HB64268                        12                              44

# %%
#As State Code and State represents same data deleting state column.
del auto['State']

auto.head()
# Out:
#                      Gender  Income Employment Status Education  \
# customer_id Customer
# 0           BU79786       F   56274          Employed  Bachelor
# 1           QZ44356       F       0        Unemployed  Bachelor
# 2           AI49188       F   48767          Employed  Bachelor
# 3           WW63253       M       0        Unemployed  Bachelor
# 4           HB64268       M   43836          Employed  Bachelor
#
#                      Marital Status Country State Code Location Type  \
# customer_id Customer
# 0           BU79786         Married      US         KS      Suburban
# 1           QZ44356          Single      US         NE      Suburban
# 2           AI49188         Married      US         OK      Suburban
# 3           WW63253         Married      US         MO      Suburban
# 4           HB64268          Single      US         KS         Rural
#
#                        Policy Name     Policy Type  Number of Policies  \
# customer_id Customer
# 0           BU79786   Corporate L3  Corporate Auto                   1
# 1           QZ44356    Personal L3   Personal Auto                   8
# 2           AI49188    Personal L3   Personal Auto                   2
# 3           WW63253   Corporate L2  Corporate Auto                   7
# 4           HB64268    Personal L1   Personal Auto                   1
#
#                       Premium Per Month  Coverage Sales Channel  \
# customer_id Customer
# 0           BU79786                  69     Basic         Agent
# 1           QZ44356                  94  Extended         Agent
# 2           AI49188                 108   Premium         Agent
# 3           WW63253                 106     Basic   Call Center
# 4           HB64268                  73     Basic         Agent
#
#                        Vehicle Type Vehicle Size     date  Claim Reason  \
# customer_id Customer
# 0           BU79786    Two-Door Car      Medsize  2/24/11     Collision
# 1           QZ44356   Four-Door Car      Medsize  1/31/11  Scratch/Dent
# 2           AI49188    Two-Door Car      Medsize  2/19/11     Collision
# 3           WW63253             SUV      Medsize  1/20/11     Collision
# 4           HB64268   Four-Door Car      Medsize   2/3/11     Collision
#
#                       Claim Demanded  Claim Sanctioned  \
# customer_id Customer
# 0           BU79786       276.351928        384.811147
# 1           QZ44356       697.953590       1131.464935
# 2           AI49188      1288.743165        566.472247
# 3           WW63253       764.586183        529.881344
# 4           HB64268       281.369258        138.130879
#
#                       Number of Open Complaints Response  \
# customer_id Customer
# 0           BU79786                           0       No
# 1           QZ44356                           0       No
# 2           AI49188                           0       No
# 3           WW63253                           0       No
# 4           HB64268                           0       No
#
#                       Months Since Last Claim  Months Since Policy Inspection
# customer_id Customer
# 0           BU79786                        32                               5
# 1           QZ44356                        13                              42
# 2           AI49188                        18                              38
# 3           WW63253                        18                              65
# 4           HB64268                        12                              44

# %%
#Changing the date format for making further computation easy. 
auto.assign(date=lambda x: pd.to_datetime(x['date'], format='%m/%d/%y'))
# Out:
#                      Gender  Income Employment Status Education  \
# customer_id Customer
# 0           BU79786       F   56274          Employed  Bachelor
# 1           QZ44356       F       0        Unemployed  Bachelor
# 2           AI49188       F   48767          Employed  Bachelor
# 3           WW63253       M       0        Unemployed  Bachelor
# 4           HB64268       M   43836          Employed  Bachelor
# ...                     ...     ...               ...       ...
# 9129        LA72316       M   71941          Employed  Bachelor
# 9130        PK87824       F   21604          Employed   College
# 9131        TD14365       M       0        Unemployed  Bachelor
# 9132        UP19263       M   21941          Employed   College
# 9133        Y167826       M       0        Unemployed   College
#
#                      Marital Status Country State Code Location Type  \
# customer_id Customer
# 0           BU79786         Married      US         KS      Suburban
# 1           QZ44356          Single      US         NE      Suburban
# 2           AI49188         Married      US         OK      Suburban
# 3           WW63253         Married      US         MO      Suburban
# 4           HB64268          Single      US         KS         Rural
# ...                             ...     ...        ...           ...
# 9129        LA72316         Married      US         MO         Urban
# 9130        PK87824        Divorced      US         MO      Suburban
# 9131        TD14365          Single      US         MO      Suburban
# 9132        UP19263         Married      US         MO      Suburban
# 9133        Y167826          Single      US         MO      Suburban
#
#                        Policy Name     Policy Type  Number of Policies  \
# customer_id Customer
# 0           BU79786   Corporate L3  Corporate Auto                   1
# 1           QZ44356    Personal L3   Personal Auto                   8
# 2           AI49188    Personal L3   Personal Auto                   2
# 3           WW63253   Corporate L2  Corporate Auto                   7
# 4           HB64268    Personal L1   Personal Auto                   1
# ...                            ...             ...                 ...
# 9129        LA72316    Personal L1   Personal Auto                   2
# 9130        PK87824   Corporate L3  Corporate Auto                   1
# 9131        TD14365   Corporate L2  Corporate Auto                   2
# 9132        UP19263    Personal L2   Personal Auto                   3
# 9133        Y167826   Corporate L3  Corporate Auto                   1
#
#                       Premium Per Month  Coverage Sales Channel  \
# customer_id Customer
# 0           BU79786                  69     Basic         Agent
# 1           QZ44356                  94  Extended         Agent
# 2           AI49188                 108   Premium         Agent
# 3           WW63253                 106     Basic   Call Center
# 4           HB64268                  73     Basic         Agent
# ...                                 ...       ...           ...
# 9129        LA72316                  73     Basic           Web
# 9130        PK87824                  79  Extended        Branch
# 9131        TD14365                  85  Extended        Branch
# 9132        UP19263                  96  Extended        Branch
# 9133        Y167826                  77  Extended   Call Center
#
#                        Vehicle Type Vehicle Size       date  Claim Reason  \
# customer_id Customer
# 0           BU79786    Two-Door Car      Medsize 2011-02-24     Collision
# 1           QZ44356   Four-Door Car      Medsize 2011-01-31  Scratch/Dent
# 2           AI49188    Two-Door Car      Medsize 2011-02-19     Collision
# 3           WW63253             SUV      Medsize 2011-01-20     Collision
# 4           HB64268   Four-Door Car      Medsize 2011-02-03     Collision
# ...                             ...          ...        ...           ...
# 9129        LA72316   Four-Door Car      Medsize 2011-02-10          Hail
# 9130        PK87824   Four-Door Car      Medsize 2011-02-12     Collision
# 9131        TD14365   Four-Door Car      Medsize 2011-02-06     Collision
# 9132        UP19263   Four-Door Car        Large 2011-02-03  Scratch/Dent
# 9133        Y167826    Two-Door Car      Medsize 2011-02-14         Other
#
#                       Claim Demanded  Claim Sanctioned  \
# customer_id Customer
# 0           BU79786       276.351928        384.811147
# 1           QZ44356       697.953590       1131.464935
# 2           AI49188      1288.743165        566.472247
# 3           WW63253       764.586183        529.881344
# 4           HB64268       281.369258        138.130879
# ...                              ...               ...
# 9129        LA72316      2340.598798        198.234764
# 9130        PK87824       309.651122        379.200000
# 9131        TD14365       816.389043        790.784983
# 9132        UP19263       752.444244        691.200000
# 9133        Y167826       261.183687        369.600000
#
#                       Number of Open Complaints Response  \
# customer_id Customer
# 0           BU79786                           0       No
# 1           QZ44356                           0       No
# 2           AI49188                           0       No
# 3           WW63253                           0       No
# 4           HB64268                           0       No
# ...                                         ...      ...
# 9129        LA72316                           0       No
# 9130        PK87824                           0      Yes
# 9131        TD14365                           3       No
# 9132        UP19263                           0       No
# 9133        Y167826                           0       No
#
#                       Months Since Last Claim  Months Since Policy Inspection
# customer_id Customer
# 0           BU79786                        32                               5
# 1           QZ44356                        13                              42
# 2           AI49188                        18                              38
# 3           WW63253                        18                              65
# 4           HB64268                        12                              44
# ...                                       ...                             ...
# 9129        LA72316                        18                              89
# 9130        PK87824                        14                              28
# 9131        TD14365                         9                              37
# 9132        UP19263                        34                               3
# 9133        Y167826                         3                              90
#
# [9134 rows x 24 columns]

# %% [markdown]
# ## Questions

# %% [raw]
# Question 1: Can we predict amount of premium per month based on other attributes?
#
# Data: Gender,Income,Employment Status,Education,Marital Status,State Code,Location Type,Policy Name,Policy Type,Premium Per Month,Vehicle Type,Vehicle Size,Date.
#
# Second way: Past Data can help in getting prediction more accurate.
#
# Assumptions: There is no other attributes on which amount of premium of policy depends.
#
# Statement: We will be able to predict the amount of premium of policy

# %% [raw]
# Question 2: How many policies sold through each sales channels
#
# Data: No. of policies for each customers and Through which sales channel each customers.
#
# Second Way: Sales Channels used by other insurance company can help increasing sales.
#
# Statement: Using this analysis insurance company can predict through which sales channel their is sales is maximum and they can increase expenditure in that sales channels to increase their sales
